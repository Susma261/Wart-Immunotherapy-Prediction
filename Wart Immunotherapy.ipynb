# %%
import numpy as np 
import pandas as pd

# %%
file_path = 'C:/Users/Susma/Documents/Susma 8th sem/Decision Support Systems/Immunotherapy.xlsx'
data = pd.read_excel(file_path) 

data
# Out:
#     sex  age   Time  Number_of_Warts  Type  Area  induration_diameter  \
# 0     1   22   2.25               14     3    51                   50
# 1     1   15   3.00                2     3   900                   70
# 2     1   16  10.50                2     1   100                   25
# 3     1   27   4.50                9     3    80                   30
# 4     1   20   8.00                6     1    45                    8
# ..  ...  ...    ...              ...   ...   ...                  ...
# 85    1   40   5.50                8     3    69                    5
# 86    1   38   7.50                8     2    56                   45
# 87    1   46  11.50                4     1    91                   25
# 88    1   32  12.00                9     1    43                   50
# 89    2   23   6.75                6     1    19                    2
#
#     Result_of_Treatment
# 0                     1
# 1                     1
# 2                     1
# 3                     1
# 4                     1
# ..                  ...
# 85                    1
# 86                    1
# 87                    0
# 88                    0
# 89                    1
#
# [90 rows x 8 columns]

# %%
data.describe().T
# Out:
#                      count       mean         std   min    25%    50%  \
# sex                   90.0   1.544444    0.500811   1.0   1.00   2.00
# age                   90.0  31.044444   12.235435  15.0  20.25  28.50
# Time                  90.0   7.230556    3.098166   1.0   5.00   7.75
# Number_of_Warts       90.0   6.144444    4.212238   1.0   2.00   6.00
# Type                  90.0   1.711111    0.824409   1.0   1.00   1.00
# Area                  90.0  95.700000  136.614643   6.0  35.50  53.00
# induration_diameter   90.0  14.333333   17.217707   2.0   5.00   7.00
# Result_of_Treatment   90.0   0.788889    0.410383   0.0   1.00   1.00
#
#                          75%    max
# sex                   2.0000    2.0
# age                  41.7500   56.0
# Time                  9.9375   12.0
# Number_of_Warts       8.7500   19.0
# Type                  2.0000    3.0
# Area                 80.7500  900.0
# induration_diameter   9.0000   70.0
# Result_of_Treatment   1.0000    1.0

# %%
#check null values
cols_with_missing = [col for col in data.columns
                     if data[col].isnull().any()]

# %%
sns.countplot(data['Result_of_Treatment'],label="Sum")
data['Result_of_Treatment'].value_counts()
# Out:
# C:\Users\Susma\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 1    71
# 0    19
# Name: Result_of_Treatment, dtype: int64

# %%
pd.concat([data.groupby('Result_of_Treatment').mean(), data.groupby('Result_of_Treatment').mean().diff().dropna()]).T
# Out:
# Result_of_Treatment          0          1          1
# sex                   1.526316   1.549296   0.022980
# age                  35.473684  29.859155  -5.614529
# Time                  9.381579   6.654930  -2.726649
# Number_of_Warts       6.526316   6.042254  -0.484062
# Type                  1.578947   1.746479   0.167532
# Area                 84.315789  98.746479  14.430689
# induration_diameter  15.368421  14.056338  -1.312083

# %%
fig = plt.figure()
fig.subplots_adjust(hspace=0.4, wspace=0.4)
ax = fig.add_subplot(2, 2, 1)
ax = sns.distplot( data[data['Result_of_Treatment'] == 0]['age'] , color="skyblue", label="0", ax = ax)
ax = sns.distplot( data[data['Result_of_Treatment'] == 1]['age'] , color="red", label="1", ax = ax)
ax.legend()
ax = fig.add_subplot(2, 2, 2)
ax = sns.distplot( data[data['Result_of_Treatment'] == 0]['Time'] , color="skyblue", label="0")
ax = sns.distplot( data[data['Result_of_Treatment'] == 1]['Time'] , color="red", label="1")
ax.legend()
ax = fig.add_subplot(2, 2, 3)
ax = sns.distplot( data[data['Result_of_Treatment'] == 0]['Number_of_Warts'] , color="skyblue", label="0")
ax = sns.distplot( data[data['Result_of_Treatment'] == 1]['Number_of_Warts'] , color="red", label="1")
ax.legend()
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax = fig.add_subplot(2, 2, 4)
ax = sns.distplot( data[data['Result_of_Treatment'] == 0]['Area'] , color="skyblue", label="0", ax = ax)
ax = sns.distplot( data[data['Result_of_Treatment'] == 1]['Area'] , color="red", label="1", ax = ax)
ax.legend()
plt.show()
# Out:
# C:\Users\Susma\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Susma\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Susma\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Susma\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Susma\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Susma\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <ipython-input-8-2d09947a114c>:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# C:\Users\Susma\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Susma\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
ax = sns.distplot( data[data['Result_of_Treatment'] == 0]['age'] , color="skyblue", label="0")
ax = sns.distplot( data[data['Result_of_Treatment'] == 1]['age'] , color="red", label="1")
ax.legend()
# Out:
# C:\Users\Susma\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Susma\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
ax = sns.distplot( data[data['Result_of_Treatment'] == 0]['Time'] , color="skyblue", label="0")
ax = sns.distplot( data[data['Result_of_Treatment'] == 1]['Time'] , color="red", label="1")
ax.legend()
# Out:
# C:\Users\Susma\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Susma\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
corr = data.corr()
corr.T
# Out:
#                           sex       age      Time  Number_of_Warts      Type  \
# sex                  1.000000  0.043682 -0.014825         0.100785 -0.104623
# age                  0.043682  1.000000  0.188981         0.000092 -0.056636
# Time                -0.014825  0.188981  1.000000         0.050800 -0.262870
# Number_of_Warts      0.100785  0.000092  0.050800         1.000000  0.148047
# Type                -0.104623 -0.056636 -0.262870         0.148047  1.000000
# Area                -0.115664 -0.064334 -0.047254        -0.107528 -0.042080
# induration_diameter  0.015202 -0.007005 -0.183656         0.062383  0.205546
# Result_of_Treatment  0.018831 -0.188314 -0.361172        -0.047160  0.083396
#
#                          Area  induration_diameter  Result_of_Treatment
# sex                 -0.115664             0.015202             0.018831
# age                 -0.064334            -0.007005            -0.188314
# Time                -0.047254            -0.183656            -0.361172
# Number_of_Warts     -0.107528             0.062383            -0.047160
# Type                -0.042080             0.205546             0.083396
# Area                 1.000000             0.119262             0.043349
# induration_diameter  0.119262             1.000000            -0.031273
# Result_of_Treatment  0.043349            -0.031273             1.000000

# %%
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(7, 5))
    ax = sns.heatmap(corr, mask=mask, annot = True, 
                     vmin =-1, vmax =1, center = 0, 
                     xticklabels=corr.columns, cmap="RdBu_r")

# %%
sns.scatterplot(x=data['Time'], y=data['age'], hue=data['Result_of_Treatment'])
# Out:
# <AxesSubplot:xlabel='Time', ylabel='age'>

# %%
c = sns.FacetGrid(data, col="Type", hue="Result_of_Treatment")
c.map(plt.scatter, "Time", "age", alpha=.7)
c.add_legend();

# %%
from sklearn.model_selection import train_test_split

X = data.loc[:, data.columns != 'Result_of_Treatment']
y = data.loc[:, 'Result_of_Treatment']
train_X, test_X, train_y, test_y = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
conda install python-
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Susma\anaconda3
#
#   added / updated specs:
#     - python-graphviz
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blosc-1.21.3               |       h6c2663c_0          86 KB
#     imagecodecs-2021.8.26      |   py38hc0a7faf_1         6.0 MB
#     libarchive-3.6.2           |       hebabd0d_0         1.8 MB
#     libbrotlicommon-1.0.9      |       h2bbff1b_7          71 KB
#     libbrotlidec-1.0.9         |       h2bbff1b_7          30 KB
# Note: you may need to restart the kernel to use updated packages.
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/win-64::anaconda==custom=py38_1
#   - defaults/win-64::anaconda-navigator==2.1.1=py38_0
#   - defaults/win-64::blosc==1.21.0=h19a0ad4_0
#   - defaults/win-64::bokeh==2.4.2=py38haa95532_0
#   - defaults/noarch::dask==2021.10.0=pyhd3eb1b0_0
#   - defaults/win-64::imagecodecs==2021.8.26=py38ha1f97ea_0
#   - defaults/noarch::imageio==2.9.0=pyhd3eb1b0_0
#   - defaults/win-64::lcms2==2.12=h83e58a3_0
#   - defaults/win-64::libtiff==4.2.0=hd0e1b90_0
#   - defaults/win-64::matplotlib==3.5.0=py38haa95532_0
#   - defaults/win-64::matplotlib-base==3.5.0=py38h6214cd6_0
#   - defaults/win-64::openjpeg==2.4.0=h4fc8c34_0
#   - defaults/win-64::pillow==8.4.0=py38hd45dc43_0
#   - defaults/win-64::pytables==3.6.1=py38ha5be198_0
#   - defaults/win-64::scikit-image==0.18.3=py38hf11a4ad_0
#   - defaults/noarch::seaborn==0.11.2=pyhd3eb1b0_0
#   - defaults/noarch::tifffile==2021.7.2=pyhd3eb1b0_2
#   - defaults/win-64::_anaconda_depends==2020.07=py38_0
#     libbrotlienc-1.0.9         |       h2bbff1b_7         233 KB
#     libiconv-1.16              |       h2bbff1b_2         651 KB
#     libtiff-4.5.0              |       h8a3f274_0         1.2 MB
#     libxml2-2.9.14             |       h0ad7f3c_0         1.5 MB
#     lz4-c-1.9.4                |       h2bbff1b_0         143 KB
#     snappy-1.1.9               |       h6c2663c_0         2.2 MB
#     xz-5.2.10                  |       h8cc25b3_1         520 KB
#     zlib-1.2.13                |       h8cc25b3_0         113 KB
#     zstd-1.5.5                 |       hd43e919_0         682 KB
#     ------------------------------------------------------------
#                                            Total:        15.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   libbrotlicommon    pkgs/main/win-64::libbrotlicommon-1.0.9-h2bbff1b_7 None
#   libbrotlidec       pkgs/main/win-64::libbrotlidec-1.0.9-h2bbff1b_7 None
#   libbrotlienc       pkgs/main/win-64::libbrotlienc-1.0.9-h2bbff1b_7 None
#
# The following packages will be UPDATED:
#
#   blosc                                   1.21.0-h19a0ad4_0 --> 1.21.3-h6c2663c_0 None
#   imagecodecs                      2021.8.26-py38ha1f97ea_0 --> 2021.8.26-py38hc0a7faf_1 None
#   libarchive                               3.4.2-h5e25573_0 --> 3.6.2-hebabd0d_0 None
#   libiconv                                  1.15-h1df5818_7 --> 1.16-h2bbff1b_2 None
#   libtiff                                  4.2.0-hd0e1b90_0 --> 4.5.0-h8a3f274_0 None
#   libxml2                                 2.9.12-h0ad7f3c_0 --> 2.9.14-h0ad7f3c_0 None
#   lz4-c                                    1.9.3-h2bbff1b_1 --> 1.9.4-h2bbff1b_0 None
#   snappy                                   1.1.8-h33f27b4_0 --> 1.1.9-h6c2663c_0 None
#   xz                                       5.2.5-h62dcd97_0 --> 5.2.10-h8cc25b3_1 None
#   zlib                                    1.2.11-h8cc25b3_4 --> 1.2.13-h8cc25b3_0 None
#   zstd                                     1.4.9-h19a0ad4_0 --> 1.5.5-hd43e919_0 None
#
#
#
# Downloading and Extracting Packages
#
# libbrotlicommon-1.0. | 71 KB     |            |   0%
# libbrotlicommon-1.0. | 71 KB     | ##2        |  23%
# libbrotlicommon-1.0. | 71 KB     | ########## | 100%
# libbrotlicommon-1.0. | 71 KB     | ########## | 100%
#
# imagecodecs-2021.8.2 | 6.0 MB    |            |   0%
# imagecodecs-2021.8.2 | 6.0 MB    |            |   0%
# imagecodecs-2021.8.2 | 6.0 MB    | 1          |   1%
# imagecodecs-2021.8.2 | 6.0 MB    | 2          |   2%
# imagecodecs-2021.8.2 | 6.0 MB    | 3          |   3%
# imagecodecs-2021.8.2 | 6.0 MB    | 4          |   5%
# imagecodecs-2021.8.2 | 6.0 MB    | 6          |   6%
# imagecodecs-2021.8.2 | 6.0 MB    | 8          |   9%
# imagecodecs-2021.8.2 | 6.0 MB    | #1         |  12%
# imagecodecs-2021.8.2 | 6.0 MB    | #6         |  16%
# imagecodecs-2021.8.2 | 6.0 MB    | ##1        |  21%
# imagecodecs-2021.8.2 | 6.0 MB    | ##8        |  28%
# imagecodecs-2021.8.2 | 6.0 MB    | ###7       |  37%
# imagecodecs-2021.8.2 | 6.0 MB    | ####8      |  49%
# imagecodecs-2021.8.2 | 6.0 MB    | ######3    |  64%
# imagecodecs-2021.8.2 | 6.0 MB    | ########1  |  81%
# imagecodecs-2021.8.2 | 6.0 MB    | ########## | 100%
# imagecodecs-2021.8.2 | 6.0 MB    | ########## | 100%
#
# libbrotlidec-1.0.9   | 30 KB     |            |   0%
# libbrotlidec-1.0.9   | 30 KB     | ########## | 100%
# libbrotlidec-1.0.9   | 30 KB     | ########## | 100%
#
# zstd-1.5.5           | 682 KB    |            |   0%
# zstd-1.5.5           | 682 KB    | #######    |  70%
# zstd-1.5.5           | 682 KB    | ########## | 100%
#
# zlib-1.2.13          | 113 KB    |            |   0%
# zlib-1.2.13          | 113 KB    | ########## | 100%
# zlib-1.2.13          | 113 KB    | ########## | 100%
#
# snappy-1.1.9         | 2.2 MB    |            |   0%
# snappy-1.1.9         | 2.2 MB    | #9         |  19%
# snappy-1.1.9         | 2.2 MB    | #######5   |  75%
# snappy-1.1.9         | 2.2 MB    | ########## | 100%
#
# libxml2-2.9.14       | 1.5 MB    |            |   0%
# libxml2-2.9.14       | 1.5 MB    | #5         |  16%
# libxml2-2.9.14       | 1.5 MB    | #########4 |  95%
# libxml2-2.9.14       | 1.5 MB    | ########## | 100%
#
# xz-5.2.10            | 520 KB    |            |   0%
# xz-5.2.10            | 520 KB    | #########5 |  95%
# xz-5.2.10            | 520 KB    | ########## | 100%
#
# blosc-1.21.3         | 86 KB     |            |   0%
# blosc-1.21.3         | 86 KB     | ########## | 100%
# blosc-1.21.3         | 86 KB     | ########## | 100%
#
# libarchive-3.6.2     | 1.8 MB    |            |   0%
# libarchive-3.6.2     | 1.8 MB    | #9         |  19%
# libarchive-3.6.2     | 1.8 MB    | ########8  |  88%
# libarchive-3.6.2     | 1.8 MB    | ########## | 100%
#
# lz4-c-1.9.4          | 143 KB    |            |   0%
# lz4-c-1.9.4          | 143 KB    | ########## | 100%
# lz4-c-1.9.4          | 143 KB    | ########## | 100%
#
# libbrotlienc-1.0.9   | 233 KB    |            |   0%
# libbrotlienc-1.0.9   | 233 KB    | ########## | 100%
# libbrotlienc-1.0.9   | 233 KB    | ########## | 100%
#
# libtiff-4.5.0        | 1.2 MB    |            |   0%
# libtiff-4.5.0        | 1.2 MB    | ###        |  31%
# libtiff-4.5.0        | 1.2 MB    | ########## | 100%
# libtiff-4.5.0        | 1.2 MB    | ########## | 100%
#
# libiconv-1.16        | 651 KB    |            |   0%
# libiconv-1.16        | 651 KB    | #####6     |  57%
# libiconv-1.16        | 651 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Retrieving notices: ...working... done
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.9.0
#   latest version: 23.3.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %%
from sklearn.tree import DecisionTreeClassifier
clf=DecisionTreeClassifier()
clf.fit(train_X,train_y)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import mean_absolute_error



decisionTreeModel = DecisionTreeClassifier(random_state=1)
decisionTreeModel.fit(train_X, train_y)
# Out:
# DecisionTreeClassifier(random_state=1)

# %%
from sklearn.model_selection import cross_validate
from sklearn import metrics

def scoringModel(model, train, y):
    scoring = ['accuracy', 'precision_macro', 'recall_macro' , 'f1_weighted', 'roc_auc']
    scores = cross_validate(model, train, y, scoring=scoring, cv=5)
    return scores

def scoring(model):
    scoring = ['accuracy', 'precision_macro', 'recall_macro' , 'f1_weighted', 'roc_auc']
    scores = cross_validate(model, train_X, train_y, scoring=scoring, cv=5)
    for metric_name in scores.keys():
        print('%s : %f' % (metric_name, scores[metric_name].mean()))
    return scores

scoreTreeModel = scoringModel(decisionTreeModel,train_X, train_y)


cnf_matrix = metrics.confusion_matrix(test_y, decisionTreeModel.predict(test_X))
cnf_matrix
# Out:
# array([[ 5,  1],
#        [ 1, 11]], dtype=int64)

# %%
from sklearn.linear_model import LogisticRegression

LR = LogisticRegression()
scoreLR = scoring(LR)

data = {'Model' : ['Decision tree', 'Logistic regression']}

for metric_name in scoreTreeModel.keys():
    data[metric_name] = [scoreTreeModel[metric_name].mean(), scoreLR[metric_name].mean()]

df = pd.DataFrame(data) 
df.T
# Out:
# C:\Users\Susma\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Susma\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Susma\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Susma\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Susma\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# fit_time : 0.045998
# score_time : 0.015143
# test_accuracy : 0.805714
# test_precision_macro : 0.463663
# test_recall_macro : 0.515909
# test_f1_weighted : 0.747332
# test_roc_auc : 0.592677
# C:\Users\Susma\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#                                   0                    1
# Model                 Decision tree  Logistic regression
# fit_time                   0.004692             0.045998
# score_time                 0.011948             0.015143
# test_accuracy              0.860952             0.805714
# test_precision_macro       0.800524             0.463663
# test_recall_macro          0.732576             0.515909
# test_f1_weighted           0.856424             0.747332
# test_roc_auc               0.732576             0.592677

# %%
from sklearn import preprocessing

std_scale = preprocessing.StandardScaler().fit(train_X)
x_train_norm = std_scale.transform(train_X)
training_norm_X = pd.DataFrame(x_train_norm, index=train_X.index, columns=train_X.columns) 
print(training_norm_X.head())

x_test_norm = std_scale.transform(test_X)
testing_norm_X = pd.DataFrame(x_test_norm, index=test_X.index, columns=test_X.columns) 
print(testing_norm_X.head())
# Out:
#          sex       age      Time  Number_of_Warts      Type      Area  \
# 89  0.845154 -0.567469 -0.068053        -0.019511 -0.904534 -0.553681
# 70 -1.183216  1.189854  0.333569        -1.190145 -0.904534 -0.265274
# 53 -1.183216 -0.567469 -0.389350        -0.956018 -0.904534 -0.380637
# 19  0.845154 -0.303870 -0.068053        -0.956018 -0.904534 -0.647413
# 84  0.845154  2.068515  0.092596        -0.019511 -0.904534 -0.106650
#
#     induration_diameter
# 89            -0.701163
# 70            -0.640339
# 53            -0.397044
# 19            -0.457868
# 84            -0.397044
#          sex       age      Time  Number_of_Warts      Type      Area  \
# 58  0.845154  2.332113  1.538435         0.214616 -0.904534 -0.467159
# 78 -1.183216  1.189854  1.297462         0.214616 -0.904534  2.964882
# 43 -1.183216  1.717050 -0.790972        -0.956018 -0.904534 -0.452739
# 55 -1.183216  2.156381  0.172921         1.619377  1.507557 -0.380637
# 87 -1.183216  1.453452  1.458111        -0.487764 -0.904534 -0.034549
#
#     induration_diameter
# 58             2.218377
# 78            -0.397044
# 43            -0.397044
# 55            -0.518691
# 87             0.697783

# %%
training_norm_X[["age","Time",'Type',"induration_diameter"]]
# Out:
#          age      Time      Type  induration_diameter
# 89 -0.567469 -0.068053 -0.904534            -0.701163
# 70  1.189854  0.333569 -0.904534            -0.640339
# 53 -0.567469 -0.389350 -0.904534            -0.397044
# 19 -0.303870 -0.068053 -0.904534            -0.457868
# 84  2.068515  0.092596 -0.904534            -0.397044
# ..       ...       ...       ...                  ...
# 75  1.541318  0.735191  0.301511            -0.336220
# 9   0.223326  1.618759  1.507557            -0.518691
# 72  0.311193 -1.674540  0.301511            -0.397044
# 12 -1.270398 -1.674540  0.301511            -0.397044
# 37 -0.040272  0.574542 -0.904534            -0.701163
#
# [72 rows x 4 columns]

# %%
scoreTree = scoringModel(decisionTreeModel, training_norm_X, train_y)
scoreLR = scoringModel(LR, training_norm_X, train_y)

data = {'Model' : ['Decision tree', 'Logistic regression']}
for metric_name in scoreTree.keys():
    data[metric_name] = [scoreTree[metric_name].mean(), scoreLR[metric_name].mean()]

df = pd.DataFrame(data) 
df.T
# Out:
# C:\Users\Susma\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Susma\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Susma\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                                   0                    1
# Model                 Decision tree  Logistic regression
# fit_time                   0.004847             0.007894
# score_time                 0.013974             0.013786
# test_accuracy              0.860952             0.805714
# test_precision_macro       0.800524             0.463663
# test_recall_macro          0.732576             0.515909
# test_f1_weighted           0.856424             0.747332
# test_roc_auc               0.732576              0.57601

# %%
scoreTree = scoringModel(decisionTreeModel, training_norm_X[["age","Time",'Type',"induration_diameter"]], train_y)
scoreLR = scoringModel(LR, training_norm_X[["age","Time",'Type',"induration_diameter"]], train_y)

data = {'Model' : ['Decision tree', 'Logistic regression']}

for metric_name in scoreTree.keys():
    data[metric_name] = [scoreTree[metric_name].mean(), scoreLR[metric_name].mean()]

df = pd.DataFrame(data) 
df.T
# Out:
# C:\Users\Susma\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Susma\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Susma\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Susma\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                                   0                    1
# Model                 Decision tree  Logistic regression
# fit_time                    0.00429             0.007916
# score_time                  0.01226             0.012761
# test_accuracy              0.890476             0.834286
# test_precision_macro       0.876166             0.516044
# test_recall_macro          0.791667             0.533333
# test_f1_weighted           0.884416             0.766404
# test_roc_auc               0.791667             0.713889
